# %% [markdown]
# # Mortgage Performance

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Load Data

# %%
#Performance column names
per_colms= ["LoanIdentifier","MonthlyReportingPeriod", "ServiceName", "CurrentInterestRate",
            "CurrentActualPUB", "LoanAge","RemainingMonthstoMaturity","AdjustedMonthstoMaturity",
            "MaturityDate", "MetropolitanStatisticalAreaMSA","CurrentLoanDelinquencyStatus",
            "ModificationFlag", "ZeroBalanceCode", "ZeroBalanceEffectiveDate", "LastPaidInstallmentDate",
            "ForeclosureDate", "DispositionDate", "ForeclosureCosts", "PropertyPreservationAndRepairCosts",
            "AssetRecoveryCosts", "MiscellaneousHoldingExpensesAndCredits", "AssociatedTaxesForHoldingProperty",
            "NetSaleProceeds", "CreditEnhancementProceeds", "RepurchaseMake WholeProceeds", "OtherForeclosureProceeds",
            "NonInterestBearingPUB", "PrincipalForgivenessAmount", "RepurchaseMakeWholeProceedsFlag", 
            "ForeclosurePrincipalWrite-OffAmount", "ServicingActivityIndicator"];

# %%
# data2015Q1= pd.read_csv('RawData/FannieMae_SingleFamily/Performance_2015Q1.txt', sep="|", header=None, usecols=[0,1,5,6,7,8,9,10,15],names=per_colms)
# data2015Q2= pd.read_csv('RawData/FannieMae_SingleFamily/Performance_2015Q2.txt', sep="|", header=None, usecols=[0,1,5,6,7,8,9,10,15], names=per_colms)
# data2015Q3= pd.read_csv('RawData/FannieMae_SingleFamily/Performance_2015Q3.txt', sep="|", header=None, usecols=[0,1,5,6,7,8,9,10,15],names=per_colms)
# data2015Q4= pd.read_csv('RawData/FannieMae_SingleFamily/Performance_2015Q4.txt', sep="|", header=None, usecols=[0,1,5,6,7,8,9,10,15],names=per_colms)
# data2016Q1= pd.read_csv('RawData/FannieMae_SingleFamily/Performance_2016Q1.txt', sep="|", header=None, usecols=[0,1,5,6,7,8,9,10,15],names=per_colms)
# data2016Q2= pd.read_csv('RawData/FannieMae_SingleFamily/Performance_2016Q2.txt', sep="|", header=None, usecols=[0,1,5,6,7,8,9,10,15],names=per_colms)
# data2016Q3= pd.read_csv('RawData/FannieMae_SingleFamily/Performance_2016Q3.txt', sep="|", header=None, usecols=[0,1,5,6,7,8,9,10,15],names=per_colms)
# data2016Q4= pd.read_csv('RawData/FannieMae_SingleFamily/Performance_2016Q4.txt', sep="|", header=None, usecols=[0,1,5,6,7,8,9,10,15],names=per_colms)
# data2017Q1= pd.read_csv('RawData/FannieMae_SingleFamily/Performance_2017Q1.txt', sep="|", header=None, usecols=[0,1,5,6,7,8,9,10,15],names=per_colms)
# data2017Q2= pd.read_csv('RawData/FannieMae_SingleFamily/Performance_2017Q2.txt', sep="|", header=None, usecols=[0,1,5,6,7,8,9,10,15],names=per_colms)
# data2017Q3= pd.read_csv('RawData/FannieMae_SingleFamily/Performance_2017Q3.txt', sep="|", header=None, usecols=[0,1,5,6,7,8,9,10,15],names=per_colms)
# data2017Q4= pd.read_csv('RawData/FannieMae_SingleFamily/Performance_2017Q4.txt', sep="|", header=None, usecols=[0,1,5,6,7,8,9,10,15],names=per_colms)
# data2018Q1= pd.read_csv('RawData/FannieMae_SingleFamily/Performance_2018Q1.txt', sep="|", header=None, usecols=[0,1,5,6,7,8,9,10,15],names=per_colms)
# data2018Q2= pd.read_csv('RawData/FannieMae_SingleFamily/Performance_2018Q2.txt', sep="|", header=None, usecols=[0,1,5,6,7,8,9,10,15],names=per_colms)
data2018Q3= pd.read_csv('RawData/FannieMae_SingleFamily/Performance_2018Q3.txt', sep="|", header=None, usecols=[0,1,5,6,7,8,9,10,15],names=per_colms)

# %%
pd.set_option('display.max_columns', 999)
# data2015Q1
# data2015Q2
# data2015Q3
# data2015Q4
# data2016Q1
# data2016Q2
# data2016Q3
# data2016Q4
# data2017Q1
# data2017Q2
# data2017Q3
# data2017Q4
# data2018Q1
# data2018Q2
data2018Q3
# Out:
#          LoanIdentifier MonthlyReportingPeriod  LoanAge  \
# 0          100001609921             09/01/2018        0
# 1          100001609921             10/01/2018        1
# 2          100001609921             11/01/2018        2
# 3          100001609921             12/01/2018        3
# 4          100001609921             01/01/2019        4
# 5          100001609921             02/01/2019        5
# 6          100001609921             03/01/2019        6
# 7          100001609921             04/01/2019        7
# 8          100001609921             05/01/2019        8
# 9          100001609921             06/01/2019        9
# 10         100004410103             07/01/2018        0
# 11         100004410103             08/01/2018        1
# 12         100004410103             09/01/2018        2
# 13         100004410103             10/01/2018        3
# 14         100004410103             11/01/2018        4
# 15         100006157212             09/01/2018        1
# ...

# %% [markdown]
# # Filter based on Acq file Loan ID's

# %%
acq_colms=["LoanIdentifier"];
acq_data= pd.read_csv('all_acq_data.txt', sep='|', header=None, usecols=[0], names=acq_colms)

# %%
acq_data
# Out:
#          LoanIdentifier
# 0          100002091588
# 1          100004457300
# 2          100020572903
# 3          100040063822
# 4          100047753781
# 5          100051904183
# 6          100056519703
# 7          100056908658
# 8          100069006576
# 9          100072001017
# 10         100076786221
# 11         100082931207
# 12         100097819307
# 13         100097918224
# 14         100100420050
# 15         100100709559
# 16         100125690708
# 17         100147427486
# 18         100149144521
# 19         100161217377
# 20         100168689912
# 21         100175250810
# 22         100181352848
# 23         100183177137
# 24         100183896117
# 25         100192633501
# 26         100199050429
# 27         100204189319
# 28         100214261842
# 29         100221969193
# ...                 ...
# 3246727    999923056570
# 3246728    999923449201
# 3246729    999925599662
# 3246730    999925932124
# 3246731    999929455256
# 3246732    999935630934
# ...

# %%
filteredData=data2018Q3[data2018Q3.LoanIdentifier.isin(acq_data['LoanIdentifier'])]

filteredData
# Out:
#          LoanIdentifier MonthlyReportingPeriod  LoanAge  \
# 0          100001609921             09/01/2018        0
# 1          100001609921             10/01/2018        1
# 2          100001609921             11/01/2018        2
# 3          100001609921             12/01/2018        3
# 4          100001609921             01/01/2019        4
# 5          100001609921             02/01/2019        5
# 6          100001609921             03/01/2019        6
# 7          100001609921             04/01/2019        7
# 8          100001609921             05/01/2019        8
# 9          100001609921             06/01/2019        9
# 15         100006157212             09/01/2018        1
# 16         100006157212             10/01/2018        2
# 17         100006157212             11/01/2018        3
# 18         100006157212             12/01/2018        4
# 19         100006157212             01/01/2019        5
# 20         100006157212             02/01/2019        6
# ...

# %% [markdown]
# # Save DF

# %%
filteredData.to_csv(r'PerFil_2018Q3.txt', header=False, index=False,sep='|')

# %% [markdown]
# ## Data Example

# %%
#Are there any forclosures in the data set?
filteredData[filteredData.ForeclosureDate.notnull()]
# Out:
# Empty DataFrame
# Columns: [LoanIdentifier, MonthlyReportingPeriod, LoanAge, RemainingMonthstoMaturity, AdjustedMonthstoMaturity, MaturityDate, MetropolitanStatisticalAreaMSA, CurrentLoanDelinquencyStatus, ForeclosureDate]
# Index: []

# %%
#One Loan Information #SELECT A LOAN IDENTIFIER NUMBER
filteredData[filteredData.LoanIdentifier == 102419798276]
# Out:
# Empty DataFrame
# Columns: [LoanIdentifier, MonthlyReportingPeriod, LoanAge, RemainingMonthstoMaturity, AdjustedMonthstoMaturity, MaturityDate, MetropolitanStatisticalAreaMSA, CurrentLoanDelinquencyStatus, ForeclosureDate]
# Index: []

# %% [markdown]
# ## Foreclosed loans

# %%
#Restart Kernel and Change Quarter at Load Data to save in new file
data2015Q1Clean=data2015Q1[data2015Q1.ForeclosureDate.notnull()]

# %%
#Print New File
#data2015Q1Clean.to_csv(r'Per_2015Q1.txt', header=None, index=None, sep=' ', mode='a')
